# %%
import streamlit as st
import pandas as pd
import urllib
import json
from helpers import *

# %%
station_url = 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_status'
latlon_url = 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information'

# %%
df1 = query_station_status(station_url)

# %%
df2 = get_station_latlon(latlon_url)

# %%
join_latlon(df1, df2)
# Out:
#     station_id  num_bikes_available       num_bikes_available_types  \
# 0         7000                    7   {'mechanical': 7, 'ebike': 0}
# 1         7001                    0   {'mechanical': 0, 'ebike': 0}
# 2         7002                    0   {'mechanical': 0, 'ebike': 0}
# 3         7003                    1   {'mechanical': 1, 'ebike': 0}
# 4         7005                    8   {'mechanical': 8, 'ebike': 0}
# ..         ...                  ...                             ...
# 987       8182                   12  {'mechanical': 12, 'ebike': 0}
# 988       8183                    3   {'mechanical': 3, 'ebike': 0}
# 989       8184                    0   {'mechanical': 0, 'ebike': 0}
# 990       8185                    4   {'mechanical': 4, 'ebike': 0}
# 991       8189                    0   {'mechanical': 0, 'ebike': 0}
#
#      num_bikes_disabled  num_docks_available  num_docks_disabled  \
# 0                     0                   39                   1
# 1                     0                   23                   0
# 2                     1                   17                   1
# 3                     0                   14                   0
# 4                     0                   18                   0
# ..                  ...                  ...                 ...
# 987                   0                   11                   0
# 988                   1                   19                   0
# 989                   0                   15                   0
# 990                   0                    7                   0
# 991                   0                   15                   0
#
#           last_reported  is_charging_station      status  is_installed  \
# 0   2025-12-15 03:15:56                False  IN_SERVICE             1
# 1   2025-12-15 03:16:07                 True  IN_SERVICE             1
# 2   2025-12-15 03:14:58                False  IN_SERVICE             1
# 3   2025-12-15 01:24:19                False  IN_SERVICE             1
# 4   2025-12-15 03:15:05                False  IN_SERVICE             1
# ..                  ...                  ...         ...           ...
# 987 2025-12-15 03:14:44                False  IN_SERVICE             1
# 988 2025-12-15 03:14:39                False  IN_SERVICE             1
# 989 2025-12-15 03:15:51                False  IN_SERVICE             1
# 990 2025-12-15 03:17:02                False  IN_SERVICE             1
# 991 2025-12-15 03:16:06                False  IN_SERVICE             1
#
#      is_renting  is_returning traffic  mechanical  ebike        lat        lon
# 0             1             1    None           7      0  43.639832 -79.395954
# 1             1             1    None           0      0  43.664964 -79.383550
# 2             1             1    None           0      0  43.667131 -79.399555
# 3             1             1    None           1      0  43.667018 -79.402796
# 4             1             1    None           8      0  43.648001 -79.383177
# ..          ...           ...     ...         ...    ...        ...        ...
# 987           1             1    None          12      0  43.646219 -79.350049
# 988           1             1    None           3      0  43.639171 -79.427268
# 989           1             1    None           0      0  43.781334 -79.445925
# 990           1             1    None           4      0  43.713626 -79.363733
# 991           1             1    None           0      0  43.667569 -79.387494
#
# [992 rows x 17 columns]
